# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Data Analysis
# Import the dataset
heart_data = pd.read_csv('heart.csv')
heart_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Get information about the dataset
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_data.shape
# Out:
# (303, 14)

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# there is another way to find the missing values in the dataset
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Statastical information about the dataset 
heart_data.describe(include='all').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e1dcd_row0_col0, #T_e1dcd_row0_col1, #T_e1dcd_row0_col2, #T_e1dcd_row0_col3, #T_e1dcd_row0_col5, #T_e1dcd_row0_col6, #T_e1dcd_row0_col7, #T_e1dcd_row0_col8, #T_e1dcd_row0_col9, #T_e1dcd_row0_col10, #T_e1dcd_row0_col11, #T_e1dcd_row0_col12, #T_e1dcd_row0_col13, #T_e1dcd_row7_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e1dcd_row0_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_e1dcd_row1_col0, #T_e1dcd_row5_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# ...

# %%
# Count plot histogram for the feature 'age' to find out age distribution
plt.figure(figsize=(14,8)) # Size of the figure
sns.set(style="whitegrid") # Background grid
sns.countplot(heart_data.age) # Count plot based on the 'age' feature
plt.xlabel('Age') 
plt.ylabel('Count') 
plt.title('Age Distribution')
plt.show()

# %%
# Pie chart for the feature 'sex' to find out gender distribution
male = len(heart_data[heart_data['sex'] == 1]) # Assign variable 'male' as the length of '1' in the feature 'sex' 
female = len(heart_data[heart_data['sex'] == 0]) # Assign variable 'female' as the length of '0' in the feature'sex'
labels = 'Male','Female'
sizes = [male, female]
colors = ['cyan', 'violet']
explode = (0, 0.05)  # Only the second slice will explode

plt.figure(figsize=(7,6)) # Size of the figure
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False, startangle=90)
 
plt.axis('equal') # Ensure that the pie chart is drawn as a circle
plt.show()

# %%
# Data Visualization

# Visualize the number of patients having a heart disease and not having a heart disease
sns.countplot(x="target", data=heart_data)
plt.title("Number of Patients with Heart Disease (1) and Without (0)")
plt.xlabel("Heart Disease (1: Yes, 0: No)")
plt.ylabel("Count")
plt.show()

# %%
# Visualize the age and whether a patient has a disease or not
sns.histplot(x="age", hue="target", data=heart_data, bins=30, kde=True)
plt.title("Age Distribution by Heart Disease Status")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# Assuming df is the DataFrame containing the features

# Calculate the correlation matrix
correlation_matrix = heart_data.corr()

#  Visualize correlation between all features using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Features")
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# Data Preparation
X = heart_data.drop("target", axis=1)
y = heart_data["target"]

# %%
# Divide the dataset in 70:30 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Build the Logistic Regression model
log_reg_model = LogisticRegression(random_state=42)
log_reg_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Predict the values on the test set
y_pred_log_reg = log_reg_model.predict(X_test)

# Build the confusion matrix and get the accuracy score
conf_matrix_log_reg = confusion_matrix(y_test, y_pred_log_reg)
accuracy_log_reg = accuracy_score(y_test, y_pred_log_reg)

print("Confusion Matrix (Logistic Regression):")
print(conf_matrix_log_reg)
print("Accuracy Score (Logistic Regression):", accuracy_log_reg)
# Out:
# Confusion Matrix (Logistic Regression):
# [[32  9]
#  [ 8 42]]
# Accuracy Score (Logistic Regression): 0.8131868131868132

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
# Build the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

# Predict the values on the test set
y_pred_dt = dt_model.predict(X_test)

# Build the confusion matrix and calculate the accuracy
conf_matrix_dt = confusion_matrix(y_test, y_pred_dt)
accuracy_dt = accuracy_score(y_test, y_pred_dt)

print("Confusion Matrix (Decision Tree):")
print(conf_matrix_dt)
print("Accuracy Score (Decision Tree):", accuracy_dt)
# Out:
# Confusion Matrix (Decision Tree):
# [[32  9]
#  [15 35]]
# Accuracy Score (Decision Tree): 0.7362637362637363

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Build the Random Forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

# Predict the values on the test set
y_pred_rf = rf_model.predict(X_test)

# Build the confusion matrix and calculate the accuracy
conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
accuracy_rf = accuracy_score(y_test, y_pred_rf)

print("Confusion Matrix (Random Forest):")
print(conf_matrix_rf)
print("Accuracy Score (Random Forest):", accuracy_rf)
# Out:
# Confusion Matrix (Random Forest):
# [[33  8]
#  [ 8 42]]
# Accuracy Score (Random Forest): 0.8241758241758241

# %% [markdown]
# # Select the Best Model

# %%
from sklearn.metrics import classification_report

# Print the confusion matrix of all classifiers
print("Confusion Matrix (Logistic Regression):")
print(conf_matrix_log_reg)
print("Confusion Matrix (Decision Tree):")
print(conf_matrix_dt)
print("Confusion Matrix (Random Forest):")
print(conf_matrix_rf)
# Out:
# Confusion Matrix (Logistic Regression):
# [[32  9]
#  [ 8 42]]
# Confusion Matrix (Decision Tree):
# [[32  9]
#  [15 35]]
# Confusion Matrix (Random Forest):
# [[33  8]
#  [ 8 42]]

# %%
# Print the classification report of all classifiers
print("Classification Report (Logistic Regression):")
print(classification_report(y_test, y_pred_log_reg))
print("Classification Report (Decision Tree):")
print(classification_report(y_test, y_pred_dt))
print("Classification Report (Random Forest):")
print(classification_report(y_test, y_pred_rf))
# Out:
# Classification Report (Logistic Regression):
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        41
#            1       0.82      0.84      0.83        50
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91
#
# Classification Report (Decision Tree):
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73        41
#            1       0.80      0.70      0.74        50
#
#     accuracy                           0.74        91
#    macro avg       0.74      0.74      0.74        91
# weighted avg       0.74      0.74      0.74        91
#
# Classification Report (Random Forest):
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        41
#            1       0.84      0.84      0.84        50
#
# ...

# %%
# Calculate Recall, Precision, and F1 score of all the models
from sklearn.metrics import recall_score, precision_score, f1_score

recall_log_reg = recall_score(y_test, y_pred_log_reg)
precision_log_reg = precision_score(y_test, y_pred_log_reg)
f1_score_log_reg = f1_score(y_test, y_pred_log_reg)

recall_dt = recall_score(y_test, y_pred_dt)
precision_dt = precision_score(y_test, y_pred_dt)
f1_score_dt = f1_score(y_test, y_pred_dt)

recall_rf = recall_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
f1_score_rf = f1_score(y_test, y_pred_rf)

print("Logistic Regression - Recall: {}, Precision: {}, F1-score: {}".format(recall_log_reg, precision_log_reg, f1_score_log_reg))
print("Decision Tree - Recall: {}, Precision: {}, F1-score: {}".format(recall_dt, precision_dt, f1_score_dt))
print("Random Forest - Recall: {}, Precision: {}, F1-score: {}".format(recall_rf, precision_rf, f1_score_rf))
# Out:
# Logistic Regression - Recall: 0.84, Precision: 0.8235294117647058, F1-score: 0.8316831683168315
# Decision Tree - Recall: 0.7, Precision: 0.7954545454545454, F1-score: 0.7446808510638298
# Random Forest - Recall: 0.84, Precision: 0.84, F1-score: 0.8399999999999999

# %%
# Visualize confusion matrix using heatmaps
plt.figure(figsize=(10, 6))
sns.heatmap(conf_matrix_log_reg, annot=True, cmap="Blues", fmt="d", cbar=False)
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(conf_matrix_dt, annot=True, cmap="Greens", fmt="d", cbar=False)
plt.title("Confusion Matrix - Decision Tree")
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(conf_matrix_rf, annot=True, cmap="Oranges", fmt="d", cbar=False)
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %%
# Select the best model based on the best accuracy
accuracies = [accuracy_log_reg, accuracy_dt, accuracy_rf]
best_model_idx = accuracies.index(max(accuracies))

best_model = None
if best_model_idx == 0:
    best_model = "Logistic Regression"
elif best_model_idx == 1:
    best_model = "Decision Tree"
else:
    best_model = "Random Forest"

print("The Best Model based on Accuracy is:", best_model)
# Out:
# The Best Model based on Accuracy is: Random Forest
